# %% [markdown]
# # Web Mining Project 1
# # Twitter Differentiation
# # Student Name: Harshavardhan Reddy Bollam
# ###### TWITTER HANDLES
# ###### 1) CRISTIANO RONALDO
# ###### 2) MERCEDES BENZ
# ###### 3) TIM COOK

# %%
import tweepy
import pickle

# %%
import tweepy
from twitter_keys import consumer_key,consumer_secret,access_token,access_secret

auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

api = tweepy.API(auth)

cr_tweets = api.user_timeline('Cristiano')

with open('Cristiano_tweets.pkl','wb') as f:
    pickle.dump(cr_tweets,f)
    
import pickle
with open('Cristiano_tweets.pkl','rb') as f:
    cr_tweets=pickle.load(f)
print(cr_tweets)

import tweepy
from twitter_keys import consumer_key,consumer_secret,access_token,access_secret

auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

api = tweepy.API(auth)

mb_tweets = api.user_timeline('MercedesBenz')

with open('MercedesBenz_tweets.pkl','wb') as f:
    pickle.dump(mb_tweets,f)
    
import pickle
with open('MercedesBenz_tweets.pkl','rb') as f:
    mb_tweets=pickle.load(f)
print(mb_tweets)

import tweepy
from twitter_keys import consumer_key,consumer_secret,access_token,access_secret

auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

api = tweepy.API(auth)

tc_tweets = api.user_timeline('tim_cook')

with open('tim_cook_tweets.pkl','wb') as f:
    pickle.dump(tc_tweets,f)
    
import pickle
with open('tim_cook_tweets.pkl','rb') as f:
    tc_tweets=pickle.load(f)
print(tc_tweets)
# Out:
# [Status(_json={'created_at': 'Wed Jun 19 10:14:52 +0000 2019', 'id': 1141288228189802496, 'id_str': '1141288228189802496', 'text': "let's go 🚁 👪❤️ https://t.co/Zfe9WM9jHl", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1141288213090394112, 'id_str': '1141288213090394112', 'indices': [15, 38], 'media_url': 'http://pbs.twimg.com/media/D9arlT-X4AAgi36.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D9arlT-X4AAgi36.jpg', 'url': 'https://t.co/Zfe9WM9jHl', 'display_url': 'pic.twitter.com/Zfe9WM9jHl', 'expanded_url': 'https://twitter.com/Cristiano/status/1141288228189802496/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 505, 'resize': 'fit'}, 'large': {'w': 750, 'h': 557, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 557, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1141288213090394112, 'id_str': '1141288213090394112', 'indices': [15, 38], '
# ...

# %%
print("----------------------CRISTIANO RONALDO-----------------------------")
print("\n source of tweets ")
tweetcr = cr_tweets[0]
print(tweetcr.source)
print("\n tweet and tweet length")
tokens_ronaldo= tweetcr.text.split()
print(tokens_ronaldo)
print(len(tokens_ronaldo))
print("\n upper or lower case")
#make everything upper or lower case
lower_tokens_ronaldo = [s.lower() for s in tokens_ronaldo]
print(lower_tokens_ronaldo)
#finding out unique tokens
unique_lower = set(lower_tokens_ronaldo)
print(unique_lower)
print('unique tokens ', len(unique_lower)/len(lower_tokens_ronaldo))
print("\n devices used ")
devices = []
for tweet in cr_tweets:
    devices.append(tweet.source)
print(devices)
#print(min(diversities))
diversities_ronaldo = []
for tweet_ronaldo in cr_tweets:
    diversities_ronaldo.append(lexical_diversity(tweet_ronaldo.text))
print('Diversities: ', diversities_ronaldo)
print('Minimum Diversity is ',min(diversities_ronaldo))
print("----------------------MERCEDES BENZ-----------------------------")
print("\n source of tweets ")
tweetmb = mb_tweets[0]
print(tweetmb.source)
print("\n tweet and tweet length")
tokens_benz= tweetmb.text.split()
print(tokens_benz)
print(len(tokens_benz))
#make everything upper or lower case
print("\n upper or lower case")
lower_tokens_benz = [s.lower() for s in tokens_benz]
print(lower_tokens_benz)
#finding out unique tokens
unique_lower = set(lower_tokens_benz)
print(unique_lower)
print('unique tokens ', len(unique_lower)/len(lower_tokens_benz))
print("\n devices used ")
devices = []
for tweet in mb_tweets:
    devices.append(tweet.source)
print(devices)
#print(min(diversities))
diversities_benz = []
for tweet_benz in mb_tweets:
    diversities_benz.append(lexical_diversity(tweet_benz.text))
print('Diversities: ', diversities_benz)
print('Minimum Diversity is ',min(diversities_benz))

print("----------------------TIM COOK-----------------------------")
print("\n source of tweets ")
tweettc = tc_tweets[0]
print(tweettc.source)
print("\n tweet and tweet length")
tokens_cook= tweettc.text.split()
print(tokens_cook)
print(len(tokens_cook))
#make everything upper or lower case
print("\n upper or lower case")
lower_tokens_cook = [s.lower() for s in tokens_cook]
print(lower_tokens_cook)
#finding out unique tokens
unique_lower = set(lower_tokens_cook)
print(unique_lower)
print('unique tokens', len(unique_lower)/len(lower_tokens_cook))
print("\n devices used ")
devices = []
for tweet in tc_tweets:
    devices.append(tweet.source)
print(devices)
#print(min(diversities))
diversities_cook = []
for tweet_cook in tc_tweets:
    diversities_cook.append(lexical_diversity(tweet_cook.text))
print('Diversities: ', diversities_cook)
print('Minimum Diversity is ',min(diversities_cook))
# Out:
# ----------------------CRISTIANO RONALDO-----------------------------
#
#  source of tweets
# Twitter for iPhone
#
#  tweet and tweet length
# ["let's", 'go', '🚁', '👪❤️', 'https://t.co/Zfe9WM9jHl']
# 5
#
#  upper or lower case
# ["let's", 'go', '🚁', '👪❤️', 'https://t.co/zfe9wm9jhl']
# {'https://t.co/zfe9wm9jhl', "let's", '🚁', '👪❤️', 'go'}
# unique tokens  1.0
#
#  devices used
# ['Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter Web Client', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter Media Studio', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone', 'Twitter for iPhone']
# ...

# %%
def lexical_diversity(text):

    tokens_ronaldo = text.lower().split()

    return len(set(tokens_ronaldo))/len(tokens_ronaldo)

 

print("Lexical Diversity",lexical_diversity(tweet.text))


def lexical_diversity(text):

    tokens_benz = text.lower().split()

    return len(set(tokens_benz))/len(tokens_benz)

 

print("Lexical Diversity",lexical_diversity(tweet.text))



def lexical_diversity(text):

    tokens_cook = text.lower().split()

    return len(set(tokens_cook))/len(tokens_cook)

 

print("Lexical Diversity",lexical_diversity(tweet.text))
# Out:
# Lexical Diversity 0.9090909090909091
# Lexical Diversity 0.9090909090909091
# Lexical Diversity 0.9090909090909091

# %%
 import pickle
from nltk_helpers import get_sentiments

with open('Cristiano_tweets.pkl','rb') as f:
    tweets=pickle.load(f)
print("----------------------CRISTIANO RONALDO-----------------------------")
#print(tweets)
print(get_sentiments(tweets[0].text))
print(get_sentiments(tweets[0].text))
print(get_sentiments(tweets[1].text))
for tweet in tweets:
    print(get_sentiments(tweet.text))

import pickle
from nltk_helpers import get_sentiments

with open('MercedesBenz_tweets.pkl','rb') as f:
    tweets=pickle.load(f)
print("----------------------MERCEDES BENZ-----------------------------")
#print(tweets)
print(get_sentiments(tweets[0].text))
print(get_sentiments(tweets[0].text))
print(get_sentiments(tweets[1].text))
for tweet in tweets:
    print(get_sentiments(tweet.text))
    
import pickle
from nltk_helpers import get_sentiments

with open('tim_cook_tweets.pkl','rb') as f:
    tweets=pickle.load(f)
print("----------------------TIM COOK-----------------------------")
#print(tweets)
print(get_sentiments(tweets[0].text))
print(get_sentiments(tweets[0].text))
print(get_sentiments(tweets[1].text))
for tweet in tweets:
    print(get_sentiments(tweet.text))
# Out:
# ----------------------CRISTIANO RONALDO-----------------------------
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'compound': 0.7351}
# {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.5994}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.3802}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.5719}
# {'neg': 0.0, 'neu': 0.563, 'pos': 0.437, 'compound': 0.8774}
# ...

# %% [markdown]
# I have done Sentiment Analysis for the following twitter accounts Cristiano Ronaldo , Mercedes Benz , Tim Cook and analyzed that these three accounts tweets are both positive and negative, but mostly positive.
# I have selected these accounts as they are from different background.ronaldo is from sports , Mercedes Benz is from automibile and Tim Cook is from business,Apple.
# These accounts holders are happy and energetic people as they are having mostly positive tweets.

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#build our figure
fig = plt.figure()
# build the axes
ax = fig.add_subplot(111, projection='3d')

sentiments = [get_sentiments(tweet.text) for tweet in tweets]

# build our xs, ys, and zs
xs = []
for sent in sentiments:
    xs.append(sent['neg'])

ys = [sent['neu'] for sent in sentiments]
zs = list(map(lambda x: x['pos'], sentiments))

ax.scatter(xs, ys, zs)

#add another set of data
import pickle
with open('Cristiano_tweets.pkl', 'rb') as f:
    Cristiano_tweets = pickle.load(f)

from nltk_helpers import split_sentiments

CristianoX, CristianoY, CristianoZ = split_sentiments([get_sentiments(tweet.text) for tweet in Cristiano_tweets])
ax.scatter(CristianoX, CristianoY, CristianoZ, color='r', marker='^')

ax.set_xlabel('Negative')
ax.set_ylabel('Neutral')
ax.set_ylabel('Positive')
plt.title('Cristiano')
plt.show()



from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#build our figure
fig = plt.figure()
# build the axes
ax = fig.add_subplot(111, projection='3d')

sentiments = [get_sentiments(tweet.text) for tweet in tweets]

# build our xs, ys, and zs
xs = []
for sent in sentiments:
    xs.append(sent['neg'])

ys = [sent['neu'] for sent in sentiments]
zs = list(map(lambda x: x['pos'], sentiments))

ax.scatter(xs, ys, zs)

#add another set of data
import pickle
with open('MercedesBenz_tweets.pkl', 'rb') as f:
    MercedesBenz_tweets = pickle.load(f)

from nltk_helpers import split_sentiments

MercedesBenzX, MercedesBenzY, MercedesBenzZ = split_sentiments([get_sentiments(tweet.text) for tweet in MercedesBenz_tweets])
ax.scatter(MercedesBenzX, MercedesBenzY, MercedesBenzZ, color='r', marker='^')

ax.set_xlabel('Negative')
ax.set_ylabel('Neutral')
ax.set_ylabel('Positive')
plt.title('MercedesBenz')
plt.show()



from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#build our figure
fig = plt.figure()
# build the axes
ax = fig.add_subplot(111, projection='3d')

sentiments = [get_sentiments(tweet.text) for tweet in tweets]

# build our xs, ys, and zs
xs = []
for sent in sentiments:
    xs.append(sent['neg'])

ys = [sent['neu'] for sent in sentiments]
zs = list(map(lambda x: x['pos'], sentiments))

ax.scatter(xs, ys, zs)

#add another set of data
import pickle
with open('tim_cook_tweets.pkl', 'rb') as f:
    tim_cook_tweets = pickle.load(f)

from nltk_helpers import split_sentiments

tim_cookX, tim_cookY, tim_cookZ = split_sentiments([get_sentiments(tweet.text) for tweet in tim_cook_tweets])
ax.scatter(tim_cookX, tim_cookY, tim_cookZ, color='r', marker='^')

ax.set_xlabel('Negative')
ax.set_ylabel('Neutral')
ax.set_ylabel('Positive')
plt.title('tim_cook')
plt.show()



plt.scatter(xs,zs,label='Cristiano')
plt.scatter(MercedesBenzX,MercedesBenzZ,color='r',marker='*',label='MercedesBenz')
plt.scatter(tim_cookX,tim_cookZ,color='y',marker='d',label='tim_cook')
plt.xlabel('negative')
plt.ylabel('positive')
plt.title('positive vs negative Sentiments')
plt.legend(loc='upper right',shadow=True)
plt.show()
